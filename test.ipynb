# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('2024-02-sussex-street.csv')

# Display the first few rows of the dataframe to verify it was loaded correctly
df.head()
# Out:
#                                             Crime ID    Month    Reported by  \
# 0  f217986eb8a8835cd11a5c72c514b52307387a9c588dec...  2024-02  Sussex Police
# 1  c22db18edac0a2fd8210656bb37fb2c3bb84ca4d4f53c6...  2024-02  Sussex Police
# 2  b367b467b3387564dbe00356bc701ce107452c09b599b1...  2024-02  Sussex Police
# 3  1db867955b2b627d435fa4a519c1c88682d26065f6a177...  2024-02  Sussex Police
# 4  7f65b9a523d67957af00a9589e4b71db6f3dfb00b1682d...  2024-02  Sussex Police
#
#     Falls within  Longitude   Latitude                         Location  \
# 0  Sussex Police  -0.219827  50.835561       On or near Manor Hall Road
# 1  Sussex Police  -0.226087  50.837905        On or near Hadrian Avenue
# 2  Sussex Police  -0.228641  50.837961        On or near Park Way Close
# 3  Sussex Police  -0.228362  50.840071     On or near Mile Oak Crescent
# 4  Sussex Police  -0.225824  50.841093  On or near Prince Charles Close
#
#    LSOA code  LSOA name                    Crime type  \
# 0  E01031349  Adur 001A                  Public order
# 1  E01031349  Adur 001A                 Vehicle crime
# 2  E01031349  Adur 001A  Violence and sexual offences
# 3  E01031350  Adur 001B     Criminal damage and arson
# 4  E01031350  Adur 001B                   Other theft
#
#                            Last outcome category  Context
# 0                            Under investigation      NaN
# 1                            Under investigation      NaN
# 2                            Under investigation      NaN
# 3                            Under investigation      NaN
# 4  Investigation complete; no suspect identified      NaN

# %%
df.describe()
# Out:
#           Longitude      Latitude  Context
# count  11189.000000  11189.000000      0.0
# mean      -0.128677     50.896506      NaN
# std        0.362600      0.117595      NaN
# min       -0.929956     50.724668      NaN
# 25%       -0.355213     50.820003      NaN
# 50%       -0.153050     50.840301      NaN
# 75%        0.049087     50.964174      NaN
# max        0.861476     51.471342      NaN

# %%
df.isnull().sum()
# Out:
# Crime ID                  1558
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                  379
# Latitude                   379
# Location                     0
# LSOA code                  379
# LSOA name                  379
# Crime type                   0
# Last outcome category     1558
# Context                  11568
# dtype: int64

# %%
plt.scatter(df['Longitude'], df['Latitude'], s=1)

# %%
df['Location'].value_counts()
# Out:
# Location
# On or near Supermarket        1081
# On or near Parking Area        541
# No Location                    379
# On or near Shopping Area       277
# On or near Petrol Station      153
#                               ...
# On or near Perryfield Road       1
# On or near Osney Close           1
# On or near Goffs Park Road       1
# On or near Ash Keys              1
# On or near Langney Rise          1
# Name: count, Length: 4078, dtype: int64

# %%
df['Crime type'].value_counts()
# Out:
# Crime type
# Violence and sexual offences    4005
# Anti-social behaviour           1558
# Shoplifting                     1395
# Criminal damage and arson        995
# Public order                     948
# Other theft                      755
# Vehicle crime                    494
# Drugs                            352
# Burglary                         339
# Other crime                      272
# Possession of weapons            184
# Theft from the person            101
# Bicycle theft                     95
# Robbery                           75
# Name: count, dtype: int64

# %%
df['Last outcome category'].value_counts()
# Out:
# Last outcome category
# Under investigation                                    8618
# Investigation complete; no suspect identified           773
# Unable to prosecute suspect                             412
# Awaiting court outcome                                   80
# Local resolution                                         66
# Offender given a caution                                 32
# Action to be taken by another organisation               16
# Further investigation is not in the public interest       6
# Further action is not in the public interest              5
# Formal action is not in the public interest               2
# Name: count, dtype: int64

# %%
crime_type_colors = {
    'Violence and sexual offences': 'red',
    'Anti-social behaviour': 'blue',
    'Shoplifting': 'green',
    'Criminal damage and arson': 'orange',
    'Public order': 'purple',
    'Other theft': 'brown',
    'Vehicle crime': 'pink',
    'Drugs': 'gray',
    'Burglary': 'cyan',
    'Other crime': 'magenta',
    'Possession of weapons': 'yellow',
    'Theft from the person': 'olive',
    'Bicycle theft': 'teal',
    'Robbery': 'navy'
}

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.scatterplot(data=df, x='Longitude', y='Latitude', hue='Crime type', size=0.5,palette=crime_type_colors)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Longitude and Latitude Colored by Crime Type')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Adjust the legend position if needed
plt.show()
